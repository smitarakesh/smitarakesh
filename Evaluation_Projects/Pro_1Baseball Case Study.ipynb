# %% [markdown]
# # Baseball Case Study

# %%
# Improting Laibraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Loading Dataset
df = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# ## Problem Statement
#
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# -- Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, Complete Games and Errors
#
# -- Output: Number of predicted wins (W)
#
# To understand the columns meaning, follow the link given below to understand the baseball statistics: https://en.wikipedia.org/wiki/Baseball_statistics
#
# ### Columns Meaning
#      W: Win
#      R: Runs
#     AB: At Bats
#      H: Hits
#     2B: Doubles
#     3B: Triples
#     HR: Homeruns
#     BB: Walks
#     SO: Strikeouts
#     SB: Stolen Bases
#     RA: Runs Allowed
#     ER: Earned Runs
#     ERA: Earned Run Average (ERA)
#     CG: Complete Games
#     SHO: Shutouts
#     SV: Saves
#     E: Errors

# %% [markdown]
# Target variable is 'W' (Win-number of games where pitcher was pitching while their team took the lead and went on to win)

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
#checking null values
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# 0 null values

# %%
#columns name
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
#checking data types
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# No need to change the datatype they are appropriate. So, there is no need of data conversion step.

# %%
#Number of rows and columns
df.shape
# Out:
# (30, 17)

# %%
# Information about dataframe like datatype, column names etc
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.describe(), annot=True, linewidth=0.1 ,linecolor="black", fmt="0.2f")
# Out:
# <AxesSubplot:>

# %%
df.skew() # acceptable range is +/-0.5
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# ## Visualization

# %%
df_visualization=df[['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER', 'ERA', 'CG', 'SHO', 'SV', 'E']].copy()

# %%
sns.distplot(df_visualization['R'], kde=True)
plt.xlabel('Runs')
# Out:
# Text(0.5, 0, 'Runs')

# %% [markdown]
# R – Runs scored: number of times a player crosses home plate

# %%
sns.distplot(df_visualization['AB'], kde=True)
plt.xlabel('At Bats')
# Out:
# Text(0.5, 0, 'At Bats')

# %% [markdown]
# AB – At bat: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction

# %%
sns.distplot(df_visualization['H'], kde=True)
plt.xlabel('Hits')
# Out:
# Text(0.5, 0, 'Hits')

# %% [markdown]
# H – Hit: reaching base because of a batted, fair ball without error by the defense

# %%
sns.distplot(df_visualization['2B'], kde=True)
plt.xlabel('Doubles')
# Out:
# Text(0.5, 0, 'Doubles')

# %% [markdown]
# 2B – Double: hits on which the batter reaches second base safely without the contribution of a fielding error

# %%
sns.distplot(df_visualization['3B'], kde=True)
plt.xlabel('Triples')
# Out:
# Text(0.5, 0, 'Triples')

# %% [markdown]
# 3B – Triple: hits on which the batter reaches third base safely without the contribution of a fielding error

# %%
sns.distplot(df_visualization['HR'], kde=True)
plt.xlabel('Homeruns')
# Out:
# Text(0.5, 0, 'Homeruns')

# %% [markdown]
# HR – Home runs: hits on which the batter successfully touched all four bases, without the contribution of a fielding error

# %%
sns.distplot(df_visualization['BB'], kde=True)
plt.xlabel('Walks')
# Out:
# Text(0.5, 0, 'Walks')

# %% [markdown]
# BB – Base on balls (also called a "walk"): times pitching four balls, allowing the batter to take first base

# %%
sns.distplot(df_visualization['SO'], kde=True)
plt.xlabel('Strikeouts')
# Out:
# Text(0.5, 0, 'Strikeouts')

# %% [markdown]
# SO (or K) – Strikeout: number of batters who received strike three

# %%
sns.distplot(df_visualization['SB'], kde=True)
plt.xlabel('Stolen Bases')
# Out:
# Text(0.5, 0, 'Stolen Bases')

# %% [markdown]
# SB – Stolen base: number of bases advanced by the runner while the ball is in the possession of the defense

# %%
sns.distplot(df_visualization['RA'], kde=True)
plt.xlabel('Runs Allowed')
# Out:
# Text(0.5, 0, 'Runs Allowed')

# %% [markdown]
# RA (or HRA) – Home runs allowed: total home runs allowed

# %%
sns.distplot(df_visualization['ER'], kde=True)
plt.xlabel('Earned Runs')
# Out:
# Text(0.5, 0, 'Earned Runs')

# %% [markdown]
# ER – Earned run: number of runs that did not occur as a result of errors or passed balls

# %%
sns.distplot(df_visualization['ERA'], kde=True)
plt.xlabel(' Earned Run Average (ERA)')
# Out:
# Text(0.5, 0, ' Earned Run Average (ERA)')

# %% [markdown]
# ERA – Earned run average: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched

# %%
sns.distplot(df_visualization['CG'], kde=True)
plt.xlabel('Complete Games')
# Out:
# Text(0.5, 0, 'Complete Games')

# %% [markdown]
# CG – Complete game: number of games where player was the only pitcher for their team

# %%
sns.distplot(df_visualization['SHO'], kde=True)
plt.xlabel('Shutouts')
# Out:
# Text(0.5, 0, 'Shutouts')

# %% [markdown]
# SHO – Shutout: number of complete games pitched with no runs allowed

# %%
sns.distplot(df_visualization['SV'], kde=True)
plt.xlabel('Saves')
# Out:
# Text(0.5, 0, 'Saves')

# %% [markdown]
# SV – Save: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings

# %%
sns.distplot(df_visualization['E'], kde=True)
plt.xlabel('Errors')
# Out:
# Text(0.5, 0, 'Errors')

# %% [markdown]
# E – Errors: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result

# %%
#Correlation of the columns with the target columns:
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
# showing correlation through the heatmap
plt.figure(figsize=(22,7))
sns.heatmap(df.corr(), annot=True, linewidths=0.1, linecolor="black", fmt="0.2f")
# Out:
# <AxesSubplot:>

# %%
# showing correlation through the Regplot
sns.regplot(x='R',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='R', ylabel='W'>

# %%
sns.regplot(x='AB',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='W'>

# %%
sns.regplot(x='H',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='H', ylabel='W'>

# %%
sns.regplot(x='2B',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='2B', ylabel='W'>

# %%
sns.regplot(x='3B',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='3B', ylabel='W'>

# %%
sns.regplot(x='HR',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='W'>

# %%
sns.regplot(x='BB',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='BB', ylabel='W'>

# %%
sns.regplot(x='SO',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='SO', ylabel='W'>

# %%
sns.regplot(x='SB',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='SB', ylabel='W'>

# %%
sns.regplot(x='RA',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='W'>

# %%
sns.regplot(x='ER',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='W'>

# %%
sns.regplot(x='ERA',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='W'>

# %%
sns.regplot(x='CG',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='W'>

# %%
sns.regplot(x='SHO',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='W'>

# %%
sns.regplot(x='SV',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='W'>

# %%
sns.regplot(x='E',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='E', ylabel='W'>

# %% [markdown]
# The number of runs, home runs, doubles, Saves, Shutouts, and Walks these columns are highly positively correlated.
# Stolen Bases, Runs Allowed, Earned Runs are highly negative correlated.
# The remaining features have less to no linear correlation with number of Wins

# %%
#Checking Outliers
fig, ax = plt.subplots(ncols=4, nrows=5, figsize=(15,10))
index = 0
ax = ax.flatten()
for col, value in df.items():
    sns.boxplot(y=col, data=df, ax=ax[index])
    index += 1
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)
plt.show()

# %% [markdown]
# R(Runs), ERA(Earned Run Average) nad E(Error) have outlires

# %%
#checking the shape of data before removing outlier
df.shape
# Out:
# (30, 17)

# %%
#outlier removal
from scipy.stats import zscore
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
df_new_z=df[(z<3).all(axis=1)]
df_new_z
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# ...

# %%
#checking the shape of new data frame after removing outlier
df_new_z.shape
# Out:
# (29, 17)

# %%
# Percentage of Data Loss

data_loss=(30-29)/30*100 
# 30(number of rows in the original dataframe) and 29 (number of rows after outlier removal)
data_loss
# Out:
# 3.3333333333333335

# %%
# Separating the columns into features and target:
features = df.drop("W",axis = 1)
target = df["W"]

# %%
features_train, features_test, target_train, target_test=train_test_split(features, target, test_size=0.2,random_state=12)

# %%
#Building MAchine Learing Models
#Linear regression model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# %%
lr = LinearRegression(normalize=True)

# %%
lr.fit(features_train,target_train)
# Out:
# LinearRegression(normalize=True)

# %%
predictions = lr.predict(features_test)

# %%
mae = mean_absolute_error(target_test,predictions)

# %%
mae
# Out:
# 5.676795069767351

# %%
## Model Cross-validation
Train_accuracy=r2_score(target_train, pred_train)
Test_accuracy=r2_score(target_test, pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,features,target,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cross fold{j} the cv score is {cv_mean} and accuracy score for training is {Train_accuracy} and accuracy for the testing is {Test_accuracy}")
    print("\n")
# Out:
# At cross fold2 the cv score is -1.2253213632736506 and accuracy score for training is -0.15838180099883425 and accuracy for the testing is -1.1916550064202602
#
#
# At cross fold3 the cv score is 0.22588460167737923 and accuracy score for training is -0.15838180099883425 and accuracy for the testing is -1.1916550064202602
#
#
# At cross fold4 the cv score is 0.2495216665436957 and accuracy score for training is -0.15838180099883425 and accuracy for the testing is -1.1916550064202602
#
#
# At cross fold5 the cv score is 0.04075540667455857 and accuracy score for training is -0.15838180099883425 and accuracy for the testing is -1.1916550064202602
#
#
# At cross fold6 the cv score is 0.2515353093718626 and accuracy score for training is -0.15838180099883425 and accuracy for the testing is -1.1916550064202602
#
#
# At cross fold7 the cv score is 0.3890804644289492 and accuracy score for training is -0.15838180099883425 and accuracy for the testing is -1.1916550064202602
#
#
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4))
plt.scatter(x=target_test, y=pred_test, color='r')
plt.plot(target_test, target_test, color='b')
plt.xlabel('Actual Win', fontsize=10)
plt.ylabel('Predicted Win', fontsize=10)
plt.title('Linear Regression', fontsize=14)
plt.show()

# %%
#Ridge regression model
from sklearn.linear_model import RidgeCV

# %%
rrm = RidgeCV(alphas=(0.01,0.1,1,10),normalize=True)

# %%
rrm.fit(features_train,target_train)
# Out:
# RidgeCV(alphas=array([ 0.01,  0.1 ,  1.  , 10.  ]), normalize=True)

# %%
predictions = rrm.predict(features_test)

# %%
mae_rrm = mean_absolute_error(target_test,predictions)

# %%
mae_rrm
# Out:
# 5.098849557144473

# %% [markdown]
# Ridge regression model is slightly better than linear regression model because it has less mean absolute error.
