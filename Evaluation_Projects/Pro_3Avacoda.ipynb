# %% [markdown]
# # Avacoda Project

# %%
# Importing Laibraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Loading Dataset
df = pd.read_csv(r'C:\Users\DELL\AppData\Local\Temp\Temp1_avocado.csv.zip\avocado.csv')
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0       48.16     8696.87     8603.62       93.25          0.0  conventional
# 1       58.33     9505.56     9408.07       97.49          0.0  conventional
# 2      130.50     8145.35     8042.21      103.14          0.0  conventional
# 3       72.58     5811.16     5677.40      133.76          0.0  conventional
# 4       75.78     6183.95     5986.26      197.69          0.0  conventional
# ...       ...         ...         ...         ...          ...           ...
# 18244    0.00    13498.67    13066.82      431.85          0.0       organic
# 18245    0.00     9264.84     8940.04      324.80          0.0       organic
# 18246  727.94     9394.11     9351.80       42.31          0.0       organic
# 18247  727.01    10969.54    10919.54       50.00          0.0       organic
# 18248  224.53    12014.15    11988.14       26.01          0.0       organic
#
#        year            region
# 0      2015            Albany
# 1      2015            Albany
# 2      2015            Albany
# 3      2015            Albany
# 4      2015            Albany
# ...     ...               ...
# 18244  2018  WestTexNewMexico
# 18245  2018  WestTexNewMexico
# 18246  2018  WestTexNewMexico
# 18247  2018  WestTexNewMexico
# 18248  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]

# %% [markdown]
# # Problem Statement:
# Avocado is a fruit consumed by people heavily in the United States.
#
# Content This data was downloaded from the Hass Avocado Board website in May of 2018 & compiled into a single CSV.
#
# The table below represents weekly 2018 retail scan data for National retail volume (units) and price. Retail scan data comes directly from retailers’ cash registers based on actual retail sales of Hass avocados.
#
# Starting in 2013, the table below reflects an expanded, multi-outlet retail data set. Multi-outlet reporting includes an aggregation of the following channels: grocery, mass, club, drug, dollar and military. The Average Price (of avocados) in the table reflects a per unit (per avocado) cost, even when multiple units (avocados) are sold in bags.
#
# The Product Lookup codes (PLU’s) in the table are only for Hass avocados. Other varieties of avocados (e.g. greenskins) are not included in this table.
#
# Some relevant columns in the dataset:
#
# Date - The date of the observation, AveragePrice - the average price of a single avocado, type - conventional or organic, year - the year ,Region - the city or region of the observation, Total Volume - Total number of avocados sold 4046 - Total number of avocados with PLU 4046 sold 4225 - Total number of avocados with PLU 4225 sold 4770 - Total number of avocados with PLU 4770 sold
#
# Inspiration /Label
#
# The dataset can be seen in two angles to find the region and find the average price .
#
# Task: One of Classification and other of Regression
#
# Do both tasks in the same .ipynb file and submit at single file.

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
#checking null values
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
#checking data types
df.dtypes
# Out:
# Unnamed: 0        int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
df.shape
# Out:
# (18249, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %% [markdown]
# We dont have any missing values. The Feature "Unnamed:0" is just a representation of the indexes, it is not important column so it's useless to keep it and we can remove it

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %% [markdown]
# Now check our data again to make sure that the Feature Unnamed:0 is removed

# %%
df
# Out:
#              Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0      2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1      2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2      2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3      2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4      2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244  2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 18245  2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 18246  2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 18247  2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 18248  2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0         8696.87     8603.62       93.25          0.0  conventional  2015
# 1         9505.56     9408.07       97.49          0.0  conventional  2015
# 2         8145.35     8042.21      103.14          0.0  conventional  2015
# 3         5811.16     5677.40      133.76          0.0  conventional  2015
# 4         6183.95     5986.26      197.69          0.0  conventional  2015
# ...           ...         ...         ...          ...           ...   ...
# 18244    13498.67    13066.82      431.85          0.0       organic  2018
# 18245     9264.84     8940.04      324.80          0.0       organic  2018
# 18246     9394.11     9351.80       42.31          0.0       organic  2018
# 18247    10969.54    10919.54       50.00          0.0       organic  2018
# 18248    12014.15    11988.14       26.01          0.0       organic  2018
#
#                  region
# 0                Albany
# 1                Albany
# 2                Albany
# 3                Albany
# 4                Albany
# ...                 ...
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico
#
# [18249 rows x 13 columns]

# %% [markdown]
# We successfully removed 'Unnamed' column

# %%
#saperating date column
df['Date']=pd.to_datetime(df['Date'])
df['Month']=df['Date'].apply(lambda x:x.month)
df['Day']=df['Date'].apply(lambda x:x.day)

# %%
df.head()
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3 2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
#
#    region  Month  Day
# 0  Albany     12   27
# 1  Albany     12   20
# 2  Albany     12   13
# 3  Albany     12    6
# 4  Albany     11   29

# %% [markdown]
# we can see the changes

# %%
df.dtypes
# Out:
# Date            datetime64[ns]
# AveragePrice           float64
# Total Volume           float64
# 4046                   float64
# 4225                   float64
# 4770                   float64
# Total Bags             float64
# Small Bags             float64
# Large Bags             float64
# XLarge Bags            float64
# type                    object
# year                     int64
# region                  object
# Month                    int64
# Day                      int64
# dtype: object

# %% [markdown]
# Our taregt vaiables are region and AveragePrice

# %%
#Describe Dataset
df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year  \
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# std    9.862424e+05  7.461785e+05  2.439660e+05   17692.894652      0.939938
# min    0.000000e+00  0.000000e+00  0.000000e+00       0.000000   2015.000000
# 25%    5.088640e+03  2.849420e+03  1.274700e+02       0.000000   2015.000000
# 50%    3.974383e+04  2.636282e+04  2.647710e+03       0.000000   2016.000000
# 75%    1.107834e+05  8.333767e+04  2.202925e+04     132.500000   2017.000000
# max    1.937313e+07  1.338459e+07  5.719097e+06  551693.650000   2018.000000
#
#               Month           Day
# count  18249.000000  18249.000000
# mean       6.177215     15.662612
# std        3.534130      8.776281
# min        1.000000      1.000000
# 25%        3.000000      8.000000
# 50%        6.000000     16.000000
# 75%        9.000000     23.000000
# max       12.000000     31.000000

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.describe(), annot=True, linewidth=0.1 ,linecolor="black", fmt="0.2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Visualization

# %%
ax = sns.countplot (x = "type", data = df)
print(df["type"].value_counts())
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %%
#checking ratio of year and price that which year had max average price
sns.barplot(x="year", y="AveragePrice", data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='AveragePrice'>

# %%
#checking ratio of year and price that which year had max average price
sns.barplot(x="Month", y="AveragePrice", data=df)
# Out:
# <AxesSubplot:xlabel='Month', ylabel='AveragePrice'>

# %%
plt.figure(figsize=(20,20))
sns.barplot(x="AveragePrice", y="region", data=df)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='region'>

# %%
sns.scatterplot(x = 'Small Bags', y = 'Total Bags', data = df)
# Out:
# <AxesSubplot:xlabel='Small Bags', ylabel='Total Bags'>

# %%
sns.scatterplot(x = 'Large Bags', y = 'Total Bags', data = df)
# Out:
# <AxesSubplot:xlabel='Large Bags', ylabel='Total Bags'>

# %%
sns.scatterplot(x = 'XLarge Bags', y = 'Total Bags', data = df)
# Out:
# <AxesSubplot:xlabel='XLarge Bags', ylabel='Total Bags'>

# %%
sns.scatterplot(x = 'AveragePrice', y = 'Total Bags', data = df)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Total Bags'>

# %%
#Encoding Dataframe
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags  type  year  region  Month  Day
# 0         8603.62       93.25          0.0   0.0  2015     0.0     12   27
# 1         9408.07       97.49          0.0   0.0  2015     0.0     12   20
# 2         8042.21      103.14          0.0   0.0  2015     0.0     12   13
# 3         5677.40      133.76          0.0   0.0  2015     0.0     12    6
# 4         5986.26      197.69          0.0   0.0  2015     0.0     11   29
# ...           ...         ...          ...   ...   ...     ...    ...  ...
# 18244    13066.82      431.85          0.0   1.0  2018    53.0      2    4
# 18245     8940.04      324.80          0.0   1.0  2018    53.0      1   28
# 18246     9351.80       42.31          0.0   1.0  2018    53.0      1   21
# 18247    10919.54       50.00          0.0   1.0  2018    53.0      1   14
# 18248    11988.14       26.01          0.0   1.0  2018    53.0      1    7
#
# [18249 rows x 14 columns]

# %%
# Correlation of the columns with the target columns:
df.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# Total Volume     -0.192752      1.000000  0.977863  0.974181  0.872202
# 4046             -0.208317      0.977863  1.000000  0.926110  0.833389
# 4225             -0.172928      0.974181  0.926110  1.000000  0.887855
# 4770             -0.179446      0.872202  0.833389  0.887855  1.000000
# Total Bags       -0.177088      0.963047  0.920057  0.905787  0.792314
# Small Bags       -0.174730      0.967238  0.925280  0.916031  0.802733
# Large Bags       -0.172940      0.880640  0.838645  0.810015  0.698471
# XLarge Bags      -0.117592      0.747157  0.699377  0.688809  0.679861
# type              0.615845     -0.232434 -0.225819 -0.232289 -0.210027
# year              0.093197      0.017193  0.003353 -0.009559 -0.036531
# region           -0.011716      0.174176  0.192073  0.145726  0.095252
# Month             0.162409     -0.024689 -0.025803 -0.022108 -0.033424
# Day               0.027386     -0.009747 -0.010159 -0.012393 -0.009009
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags      type  \
# AveragePrice   -0.177088   -0.174730   -0.172940    -0.117592  0.615845
# Total Volume    0.963047    0.967238    0.880640     0.747157 -0.232434
# 4046            0.920057    0.925280    0.838645     0.699377 -0.225819
# 4225            0.905787    0.916031    0.810015     0.688809 -0.232289
# 4770            0.792314    0.802733    0.698471     0.679861 -0.210027
# Total Bags      1.000000    0.994335    0.943009     0.804233 -0.217788
# Small Bags      0.994335    1.000000    0.902589     0.806845 -0.220535
# Large Bags      0.943009    0.902589    1.000000     0.710858 -0.193177
# XLarge Bags     0.804233    0.806845    0.710858     1.000000 -0.175483
# type           -0.217788   -0.220535   -0.193177    -0.175483  1.000000
# year            0.071552    0.063915    0.087891     0.081033 -0.000032
# region          0.175256    0.164702    0.198768     0.082281 -0.000280
# Month          -0.022724   -0.023126   -0.020187    -0.012969 -0.000085
# Day            -0.004988   -0.003870   -0.008352     0.000319 -0.000013
#
#                   year    region     Month       Day
# AveragePrice  0.093197 -0.011716  0.162409  0.027386
# Total Volume  0.017193  0.174176 -0.024689 -0.009747
# 4046          0.003353  0.192073 -0.025803 -0.010159
# 4225         -0.009559  0.145726 -0.022108 -0.012393
# 4770         -0.036531  0.095252 -0.033424 -0.009009
# Total Bags    0.071552  0.175256 -0.022724 -0.004988
# Small Bags    0.063915  0.164702 -0.023126 -0.003870
# Large Bags    0.087891  0.198768 -0.020187 -0.008352
# XLarge Bags   0.081033  0.082281 -0.012969  0.000319
# type         -0.000032 -0.000280 -0.000085 -0.000013
# year          1.000000 -0.000055 -0.177050  0.004475
# region       -0.000055  1.000000 -0.000144 -0.000021
# Month        -0.177050 -0.000144  1.000000  0.010621
# Day           0.004475 -0.000021  0.010621  1.000000

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.corr(), annot=True, linewidths=0.1, linecolor="black", fmt="0.2f")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(22,7))
df.corr()['AveragePrice'].sort_values(ascending=False).drop(['AveragePrice']).plot(kind='bar', color ='c')
plt.xlabel('Feature', fontsize = 14)
plt.ylabel('AveragePrice', fontsize=14)
plt.title('correlation', fontsize = 18)
plt.show()

# %%
plt.figure(figsize=(22,7))
df.corr()['region'].sort_values(ascending=False).drop(['region']).plot(kind='bar', color ='c')
plt.xlabel('Feature', fontsize = 14)
plt.ylabel('region', fontsize=14)
plt.title('correlation', fontsize = 18)
plt.show()

# %%
df.skew()
# Out:
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# type             0.000329
# year             0.215339
# region           0.000030
# Month            0.106617
# Day              0.014310
# dtype: float64

# %%
df.dtypes
# Out:
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type            float64
# year              int64
# region          float64
# Month             int64
# Day               int64
# dtype: object

# %%
# Outliers Checking
df.plot(kind='box', subplots = True, layout=(4,5), figsize=(15,10))
# Out:
# AveragePrice        AxesSubplot(0.125,0.71587;0.133621x0.16413)
# Total Volume     AxesSubplot(0.285345,0.71587;0.133621x0.16413)
# 4046              AxesSubplot(0.44569,0.71587;0.133621x0.16413)
# 4225             AxesSubplot(0.606034,0.71587;0.133621x0.16413)
# 4770             AxesSubplot(0.766379,0.71587;0.133621x0.16413)
# Total Bags         AxesSubplot(0.125,0.518913;0.133621x0.16413)
# Small Bags      AxesSubplot(0.285345,0.518913;0.133621x0.16413)
# Large Bags       AxesSubplot(0.44569,0.518913;0.133621x0.16413)
# XLarge Bags     AxesSubplot(0.606034,0.518913;0.133621x0.16413)
# type            AxesSubplot(0.766379,0.518913;0.133621x0.16413)
# year               AxesSubplot(0.125,0.321957;0.133621x0.16413)
# region          AxesSubplot(0.285345,0.321957;0.133621x0.16413)
# Month            AxesSubplot(0.44569,0.321957;0.133621x0.16413)
# Day             AxesSubplot(0.606034,0.321957;0.133621x0.16413)
# dtype: object

# %%
df['type'].unique()
# Out:
# array([0., 1.])

# %% [markdown]
# Since the column 'type' is nominal type, we cannot consider its data point as outlier.

# %%
df.shape
# Out:
# (18249, 14)

# %%
# Considering the outlier removal
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([  346,   359,   780, ..., 17304, 17402, 17428], dtype=int64),
#  array([2, 2, 8, ..., 0, 0, 0], dtype=int64))

# %%
df_new_z=df[(z<3).all(axis=1)]
df_new_z
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags  type  year  region  Month  Day
# 0         8603.62       93.25          0.0   0.0  2015     0.0     12   27
# 1         9408.07       97.49          0.0   0.0  2015     0.0     12   20
# 2         8042.21      103.14          0.0   0.0  2015     0.0     12   13
# 3         5677.40      133.76          0.0   0.0  2015     0.0     12    6
# 4         5986.26      197.69          0.0   0.0  2015     0.0     11   29
# ...           ...         ...          ...   ...   ...     ...    ...  ...
# 18244    13066.82      431.85          0.0   1.0  2018    53.0      2    4
# 18245     8940.04      324.80          0.0   1.0  2018    53.0      1   28
# 18246     9351.80       42.31          0.0   1.0  2018    53.0      1   21
# 18247    10919.54       50.00          0.0   1.0  2018    53.0      1   14
# 18248    11988.14       26.01          0.0   1.0  2018    53.0      1    7
#
# [17651 rows x 14 columns]

# %%
df_new_z.shape
# Out:
# (17651, 14)

# %%
#Percentage loss of data:
Data_loss=((18249 - 17651)/18249)*100
Data_loss
# Out:
# 3.276891884486821

# %% [markdown]
# # Separating the columns into features and target:

# %%
features = df.drop("AveragePrice",axis = 1)
target = df["AveragePrice"]

# %%
# Scalling the data using Min-Max Scaler:

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
for i in range(0,100):
    features_train, features_test, target_train, target_test=train_test_split(features,target,test_size=0.2,random_state=i)
    lr.fit(features_train,target_train)
    pred_train=lr.predict(features_train)
    pred_test=lr.predict(features_test)
    print(f"At random state {i}, the training accuracy is :- {r2_score(target_train, pred_train)}")
    print(f"At random state {i}, the testing accuracy is :- {r2_score(target_test, pred_test)}")
    print("\n")
# Out:
# At random state 0, the training accuracy is :- 0.4367910198866354
# At random state 0, the testing accuracy is :- 0.4475718418309924
#
#
# At random state 1, the training accuracy is :- 0.43816597803001756
# At random state 1, the testing accuracy is :- 0.4427366125944662
#
#
# At random state 2, the training accuracy is :- 0.4431058894658998
# At random state 2, the testing accuracy is :- 0.4223976244246198
#
#
# At random state 3, the training accuracy is :- 0.43986727830997296
# At random state 3, the testing accuracy is :- 0.4357412012592754
#
#
# At random state 4, the training accuracy is :- 0.44236197156648804
# At random state 4, the testing accuracy is :- 0.42574917332001483
#
#
# At random state 5, the training accuracy is :- 0.4386316372139575
# At random state 5, the testing accuracy is :- 0.43983161650034497
#
#
# At random state 6, the training accuracy is :- 0.43794598984432176
# At random state 6, the testing accuracy is :- 0.4434667981788696
#
#
# At random state 7, the training accuracy is :- 0.4396477203722847
# At random state 7, the testing accuracy is :- 0.43655390311887077
#
#
# At random state 8, the training accuracy is :- 0.43970986409312285
# At random state 8, the testing accuracy is :- 0.4360641370773165
#
#
# At random state 9, the training accuracy is :- 0.44471404985683893
# At random state 9, the testing accuracy is :- 0.4170004018771126
#
#
# At random state 10, the training accuracy is :- 0.4385835158932121
# At random state 10, the testing accuracy is :- 0.44067656182812087
#
#
# At random state 11, the training accuracy is :- 0.4377610006500623
# At random state 11, the testing accuracy is :- 0.44424021257758584
#
#
# At random state 12, the training accuracy is :- 0.4363605142507566
# At random state 12, the testing accuracy is :- 0.44940540835657783
#
#
# At random state 13, the training accuracy is :- 0.4448270462826578
# At random state 13, the testing accuracy is :- 0.4157015320473989
#
#
# At random state 14, the training accuracy is :- 0.4368118258015081
# At random state 14, the testing accuracy is :- 0.447648979072953
#
#
# At random state 15, the training accuracy is :- 0.44284136169758537
# At random state 15, the testing accuracy is :- 0.42357651841259747
#
#
# At random state 16, the training accuracy is :- 0.43886002847845085
# At random state 16, the testing accuracy is :- 0.43895903318947227
#
#
# At random state 17, the training accuracy is :- 0.4423281685561079
# At random state 17, the testing accuracy is :- 0.4260782560206733
#
#
# At random state 18, the training accuracy is :- 0.438666707710924
# At random state 18, the testing accuracy is :- 0.44051024973817465
#
#
# At random state 19, the training accuracy is :- 0.44277794161078987
# At random state 19, the testing accuracy is :- 0.42309134440011076
#
#
# At random state 20, the training accuracy is :- 0.43363299648761056
# At random state 20, the testing accuracy is :- 0.45990026931389294
#
#
# At random state 21, the training accuracy is :- 0.44143423799287074
# At random state 21, the testing accuracy is :- 0.42953409655994546
#
#
# At random state 22, the training accuracy is :- 0.4404946035578494
# At random state 22, the testing accuracy is :- 0.4328849375750007
#
#
# At random state 23, the training accuracy is :- 0.4407416749543772
# At random state 23, the testing accuracy is :- 0.43268231962856063
#
#
# At random state 24, the training accuracy is :- 0.4425573815281355
# At random state 24, the testing accuracy is :- 0.42481849219357026
#
#
# At random state 25, the training accuracy is :- 0.44035015837678415
# At random state 25, the testing accuracy is :- 0.4335098892472966
#
#
# At random state 26, the training accuracy is :- 0.43960370843264196
# At random state 26, the testing accuracy is :- 0.4368236079889469
#
#
# At random state 27, the training accuracy is :- 0.4365968219677979
# At random state 27, the testing accuracy is :- 0.44875708628728084
#
#
# At random state 28, the training accuracy is :- 0.4361188497596826
# At random state 28, the testing accuracy is :- 0.4503669425360808
#
#
# At random state 29, the training accuracy is :- 0.43791670998526155
# At random state 29, the testing accuracy is :- 0.4431226140059059
#
#
# At random state 30, the training accuracy is :- 0.44137082513618475
# At random state 30, the testing accuracy is :- 0.42909102238253716
#
#
# At random state 31, the training accuracy is :- 0.43947151455812494
# At random state 31, the testing accuracy is :- 0.4366970008806641
#
#
# At random state 32, the training accuracy is :- 0.4441342044651425
# At random state 32, the testing accuracy is :- 0.4162637982574158
#
#
# At random state 33, the training accuracy is :- 0.43858262871272735
# At random state 33, the testing accuracy is :- 0.4407716120195885
#
#
# At random state 34, the training accuracy is :- 0.44191793278620584
# At random state 34, the testing accuracy is :- 0.42718148471341544
#
#
# At random state 35, the training accuracy is :- 0.439839210948227
# At random state 35, the testing accuracy is :- 0.43554364779999
#
#
# At random state 36, the training accuracy is :- 0.44357756833649464
# At random state 36, the testing accuracy is :- 0.42071561219226694
#
#
# At random state 37, the training accuracy is :- 0.43842533834394504
# At random state 37, the testing accuracy is :- 0.44126996515154193
#
#
# At random state 38, the training accuracy is :- 0.43736168437807155
# At random state 38, the testing accuracy is :- 0.44586567054078985
#
#
# At random state 39, the training accuracy is :- 0.4405665981247294
# At random state 39, the testing accuracy is :- 0.43264928707910044
#
#
# At random state 40, the training accuracy is :- 0.4441869190045019
# At random state 40, the testing accuracy is :- 0.4154320288291008
#
#
# At random state 41, the training accuracy is :- 0.43607016763047846
# At random state 41, the testing accuracy is :- 0.45023471586381514
#
#
# At random state 42, the training accuracy is :- 0.4402893187132517
# At random state 42, the testing accuracy is :- 0.4335365071876527
#
#
# At random state 43, the training accuracy is :- 0.43988246757786065
# At random state 43, the testing accuracy is :- 0.4354046212202094
#
#
# At random state 44, the training accuracy is :- 0.44185999438013346
# At random state 44, the testing accuracy is :- 0.4277986335477838
#
#
# At random state 45, the training accuracy is :- 0.4438407907269968
# At random state 45, the testing accuracy is :- 0.4197401807929907
#
#
# At random state 46, the training accuracy is :- 0.4407847553831373
# At random state 46, the testing accuracy is :- 0.4320268275031537
#
#
# At random state 47, the training accuracy is :- 0.439499313767975
# At random state 47, the testing accuracy is :- 0.437355433969547
#
#
# At random state 48, the training accuracy is :- 0.4368814888812206
# At random state 48, the testing accuracy is :- 0.4474864378569585
#
#
# At random state 49, the training accuracy is :- 0.4382096510343787
# At random state 49, the testing accuracy is :- 0.44223606436289
#
#
# At random state 50, the training accuracy is :- 0.4357833538532906
# At random state 50, the testing accuracy is :- 0.4512699431507421
#
#
# At random state 51, the training accuracy is :- 0.43954473270990013
# At random state 51, the testing accuracy is :- 0.43691804805595025
#
#
# At random state 52, the training accuracy is :- 0.4390247350489507
# At random state 52, the testing accuracy is :- 0.43921723109401745
#
#
# At random state 53, the training accuracy is :- 0.4384291043620302
# At random state 53, the testing accuracy is :- 0.4415424766658962
#
#
# At random state 54, the training accuracy is :- 0.44076268839524546
# At random state 54, the testing accuracy is :- 0.42808963438714764
#
#
# At random state 55, the training accuracy is :- 0.43834492285577265
# At random state 55, the testing accuracy is :- 0.44052713307988156
#
#
# At random state 56, the training accuracy is :- 0.4365044318110043
# At random state 56, the testing accuracy is :- 0.44913400586704344
#
#
# At random state 57, the training accuracy is :- 0.4405924740684912
# At random state 57, the testing accuracy is :- 0.43266150917745094
#
#
# At random state 58, the training accuracy is :- 0.43985215917718035
# At random state 58, the testing accuracy is :- 0.4359608167190717
#
#
# At random state 59, the training accuracy is :- 0.4392164917469137
# At random state 59, the testing accuracy is :- 0.43850865021036256
#
#
# At random state 60, the training accuracy is :- 0.4391186521316407
# At random state 60, the testing accuracy is :- 0.4386317962844921
#
#
# At random state 61, the training accuracy is :- 0.4427493463798534
# At random state 61, the testing accuracy is :- 0.42318025607503407
#
#
# At random state 62, the training accuracy is :- 0.4367845783505534
# At random state 62, the testing accuracy is :- 0.448182424227064
#
#
# At random state 63, the training accuracy is :- 0.4380555988764876
# At random state 63, the testing accuracy is :- 0.4429197333262097
#
#
# At random state 64, the training accuracy is :- 0.4410707726140959
# At random state 64, the testing accuracy is :- 0.43056119685863903
#
#
# At random state 65, the training accuracy is :- 0.4418402530312252
# At random state 65, the testing accuracy is :- 0.4268132029563736
#
#
# At random state 66, the training accuracy is :- 0.4356033488670872
# At random state 66, the testing accuracy is :- 0.4534066522226706
#
#
# At random state 67, the training accuracy is :- 0.4388681363026258
# At random state 67, the testing accuracy is :- 0.43990477055841204
#
#
# At random state 68, the training accuracy is :- 0.4395147063883774
# At random state 68, the testing accuracy is :- 0.43714851282408385
#
#
# At random state 69, the training accuracy is :- 0.4371470753488177
# At random state 69, the testing accuracy is :- 0.4465708235921365
#
#
# At random state 70, the training accuracy is :- 0.4377343940352061
# At random state 70, the testing accuracy is :- 0.4440464727562887
#
#
# At random state 71, the training accuracy is :- 0.43661632806771256
# At random state 71, the testing accuracy is :- 0.44864228005733897
#
#
# At random state 72, the training accuracy is :- 0.4419745129043089
# At random state 72, the testing accuracy is :- 0.4271969294435999
#
#
# At random state 73, the training accuracy is :- 0.4386070732796947
# At random state 73, the testing accuracy is :- 0.44079742943374023
#
#
# At random state 74, the training accuracy is :- 0.4375772196153306
# At random state 74, the testing accuracy is :- 0.4451054719755815
#
#
# At random state 75, the training accuracy is :- 0.44324231670268777
# At random state 75, the testing accuracy is :- 0.4224964897087502
#
#
# At random state 76, the training accuracy is :- 0.43599673078049206
# At random state 76, the testing accuracy is :- 0.4510784790334017
#
#
# At random state 77, the training accuracy is :- 0.434839922319016
# At random state 77, the testing accuracy is :- 0.45441424998277213
#
#
# At random state 78, the training accuracy is :- 0.43855428744772795
# At random state 78, the testing accuracy is :- 0.44105194703683037
#
#
# At random state 79, the training accuracy is :- 0.43437243299794004
# At random state 79, the testing accuracy is :- 0.456716638758888
#
#
# At random state 80, the training accuracy is :- 0.442848701753761
# At random state 80, the testing accuracy is :- 0.42467100521531265
#
#
# At random state 81, the training accuracy is :- 0.44337488765715183
# At random state 81, the testing accuracy is :- 0.4209277237880159
#
#
# At random state 82, the training accuracy is :- 0.43931366196481414
# At random state 82, the testing accuracy is :- 0.43807543907154045
#
#
# At random state 83, the training accuracy is :- 0.4393576229927565
# At random state 83, the testing accuracy is :- 0.4378023805674387
#
#
# At random state 84, the training accuracy is :- 0.4400316920073978
# At random state 84, the testing accuracy is :- 0.43508378366757183
#
#
# At random state 85, the training accuracy is :- 0.435750807241578
# At random state 85, the testing accuracy is :- 0.45216371129967126
#
#
# At random state 86, the training accuracy is :- 0.43784111907475876
# At random state 86, the testing accuracy is :- 0.44347131926998373
#
#
# At random state 87, the training accuracy is :- 0.43838384189434465
# At random state 87, the testing accuracy is :- 0.44176164214619973
#
#
# At random state 88, the training accuracy is :- 0.43514452515014246
# At random state 88, the testing accuracy is :- 0.45365086388815234
#
#
# At random state 89, the training accuracy is :- 0.43832589057020954
# At random state 89, the testing accuracy is :- 0.44196931142492024
#
#
# At random state 90, the training accuracy is :- 0.4427473927454748
# At random state 90, the testing accuracy is :- 0.4241430340161475
#
#
# At random state 91, the training accuracy is :- 0.4403693711344502
# At random state 91, the testing accuracy is :- 0.4335725007403455
#
#
# At random state 92, the training accuracy is :- 0.43804871286979863
# At random state 92, the testing accuracy is :- 0.4424521214684799
#
#
# At random state 93, the training accuracy is :- 0.4408476935467084
# At random state 93, the testing accuracy is :- 0.43137798202047983
#
#
# At random state 94, the training accuracy is :- 0.4330698732208472
# At random state 94, the testing accuracy is :- 0.4628762355642204
#
#
# At random state 95, the training accuracy is :- 0.44124068477831535
# At random state 95, the testing accuracy is :- 0.43023362726217307
#
#
# At random state 96, the training accuracy is :- 0.43726434378013435
# At random state 96, the testing accuracy is :- 0.4451991053946879
#
#
# At random state 97, the training accuracy is :- 0.445760431467762
# At random state 97, the testing accuracy is :- 0.4123089849567688
#
#
# At random state 98, the training accuracy is :- 0.4385609685878994
# At random state 98, the testing accuracy is :- 0.4410444801719474
#
#
# At random state 99, the training accuracy is :- 0.441747379682195
# At random state 99, the testing accuracy is :- 0.42789448080146064

# %%
features_train, features_test, target_train, target_test=train_test_split(features, target, test_size=0.2,random_state=12)

# %%
lr.fit(features_train,target_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(features_test)

# %%
print(r2_score(target_test, pred_test))
# Out:
# 0.44940540835657783

# %% [markdown]
# # Cross-validation of the model:

# %%
Train_accuracy=r2_score(target_train, pred_train)
Test_accuracy=r2_score(target_test, pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,features,target,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cross fold{j} the cv score is {cv_mean} and accuracy score for training is {Train_accuracy} and accuracy for the testing is {Test_accuracy}")
    print("\n")
# Out:
# At cross fold2 the cv score is -5416.937043702285 and accuracy score for training is -0.4564805759459232 and accuracy for the testing is 0.44940540835657783
#
#
# At cross fold3 the cv score is -13.250639671431905 and accuracy score for training is -0.4564805759459232 and accuracy for the testing is 0.44940540835657783
#
#
# At cross fold4 the cv score is -12.353807352995776 and accuracy score for training is -0.4564805759459232 and accuracy for the testing is 0.44940540835657783
#
#
# At cross fold5 the cv score is -10.886791664742647 and accuracy score for training is -0.4564805759459232 and accuracy for the testing is 0.44940540835657783
#
#
# At cross fold6 the cv score is -1.0152112554989128 and accuracy score for training is -0.4564805759459232 and accuracy for the testing is 0.44940540835657783
#
#
# At cross fold7 the cv score is 0.027062684180580315 and accuracy score for training is -0.4564805759459232 and accuracy for the testing is 0.44940540835657783
#
#
# At cross fold8 the cv score is -0.04088229542273887 and accuracy score for training is -0.4564805759459232 and accuracy for the testing is 0.44940540835657783
#
#
# At cross fold9 the cv score is 0.02308425759572594 and accuracy score for training is -0.4564805759459232 and accuracy for the testing is 0.44940540835657783

# %% [markdown]
# Here we have handled the problem of the overfitting and the underfitting by checking the training and testing score.

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=target_test, y=pred_test, color='r')
plt.plot(target_test, target_test, color='b')
plt.xlabel('Actual Average Price ', fontsize=14)
plt.ylabel('Predicted Average Price', fontsize=14)
plt.title('Linear Regression', fontsize=18)
plt.show()

# %% [markdown]
# # Regularization:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import Lasso

parameters = {'alpha':[.0001, .001, .01, .1, 1, 10], 'random_state':list(range(0, 10))}
ls = Lasso()
clf = GridSearchCV(ls, parameters)
clf.fit(features_train, target_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %%
ls = Lasso(alpha = 1, random_state = 0)
ls.fit(features_train, target_train)
ls.score(features_train, target_train)
pred_ls = ls.predict(features_test)

lss = r2_score(target_test, pred_ls)
lss
# Out:
# 0.05157187813694153

# %%
cv_score=cross_val_score(ls,features,target,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# -1.1352057434222365

# %% [markdown]
# # Ensemble technique:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
parameters = {'criterion':['mse', 'mae'], 'max_features':["auto", "sqrt", "log2"]}
rf = RandomForestRegressor()
clf = GridSearchCV(rf, parameters)
clf.fit(features_train, target_train)

print(clf.best_params_)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-75-8b775aa2a3a1>", line 6, in <module>
#     clf.fit(features_train, target_train)
#   File "C:\Users\DELL\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\DELL\anaconda3\lib\site-packages\sklearn\model_selection\_search.py", line 841, in fit
#     self._run_search(evaluate_candidates)
#   File "C:\Users\DELL\anaconda3\lib\site-packages\sklearn\model_selection\_search.py", line 1288, in _run_search
#     evaluate_candidates(ParameterGrid(self.param_grid))
#   File "C:\Users\DELL\anaconda3\lib\site-packages\sklearn\model_selection\_search.py", line 795, in evaluate_candidates
#     out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#   File "C:\Users\DELL\anaconda3\lib\site-packages\joblib\parallel.py", line 1044, in __call__
#     while self.dispatch_one_batch(iterator):
#   File "C:\Users\DELL\anaconda3\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\DELL\anaconda3\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\DELL\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\DELL\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\DELL\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\DELL\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\DELL\anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\DELL\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\DELL\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\DELL\anaconda3\lib\site-packages\joblib\parallel.py", line 1044, in __call__
#     while self.dispatch_one_batch(iterator):
#   File "C:\Users\DELL\anaconda3\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\DELL\anaconda3\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\DELL\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\DELL\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\DELL\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\DELL\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\DELL\anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\DELL\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\DELL\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "C:\Users\DELL\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 389, in fit
#     builder.build(self.tree_, X, y, sample_weight)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\DELL\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\DELL\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\DELL\anaconda3\lib\inspect.py", line 1515, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\DELL\anaconda3\lib\inspect.py", line 1477, in getframeinfo
#     lines, lnum = findsource(frame)
#   File "C:\Users\DELL\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 182, in findsource
#     lines = linecache.getlines(file, globals_dict)
#   File "C:\Users\DELL\anaconda3\lib\linecache.py", line 47, in getlines
#     return updatecache(filename, module_globals)
#   File "C:\Users\DELL\anaconda3\lib\linecache.py", line 136, in updatecache
#     with tokenize.open(fullname) as fp:
#   File "C:\Users\DELL\anaconda3\lib\tokenize.py", line 394, in open
#     encoding, lines = detect_encoding(buffer.readline)
#   File "C:\Users\DELL\anaconda3\lib\tokenize.py", line 363, in detect_encoding
#     first = read_or_stop()
#   File "C:\Users\DELL\anaconda3\lib\tokenize.py", line 321, in read_or_stop
#     return readline()
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-75-8b775aa2a3a1> in <module>
#       5 clf = GridSearchCV(rf, parameters)
# ----> 6 clf.fit(features_train, target_train)
#       7
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     840
# --> 841             self._run_search(evaluate_candidates)
#     842
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1287         """Search all candidates in param_grid"""
# -> 1288         evaluate_candidates(ParameterGrid(self.param_grid))
#    1289
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     794
# --> 795                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     796                                                        X, y,
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1043
# -> 1044             while self.dispatch_one_batch(iterator):
#    1045                 pass
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     858             else:
# --> 859                 self._dispatch(tasks)
#     860                 return True
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     776             job_idx = len(self._jobs)
# --> 777             job = self._backend.apply_async(batch, callback=cb)
#     778             # A job can complete so quickly than its callback is
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#
# ~\anaconda3\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     221         with config_context(**self.config):
# --> 222             return self.function(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     592         else:
# --> 593             estimator.fit(X_train, y_train, **fit_params)
#     594
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     386             # since correctness does not rely on using threads.
# --> 387             trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#     388                              **_joblib_parallel_args(prefer='threads'))(
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1043
# -> 1044             while self.dispatch_one_batch(iterator):
#    1045                 pass
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     858             else:
# --> 859                 self._dispatch(tasks)
#     860                 return True
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     776             job_idx = len(self._jobs)
# --> 777             job = self._backend.apply_async(batch, callback=cb)
#     778             # A job can complete so quickly than its callback is
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#
# ~\anaconda3\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     221         with config_context(**self.config):
# --> 222             return self.function(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     168
# --> 169         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     170     else:
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1246
# -> 1247         super().fit(
#    1248             X, y,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     388
# --> 389         builder.build(self.tree_, X, y, sample_weight)
#     390
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2060                         # in the engines. This should return a list of strings.
# -> 2061                         stb = value._render_traceback_()
#    2062                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2061                         stb = value._render_traceback_()
#    2062                     except Exception:
# -> 2063                         stb = self.InteractiveTB.structured_traceback(etype,
#    2064                                             value, tb, tb_offset=tb_offset)
#    2065
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1122         """Return a nice text document describing the traceback."""
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#    1126
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
rf = RandomForestRegressor(criterion = "mse", max_features = "auto")
rf.fit(features_train, target_train)
rf.score(features_train, target_train)
pred_decision = rf.predict(features_test)

rfs = r2_score(target_test, pred_decision)
print('R2 Score: ', rfs*100)

rfscore = cross_val_score(rf, features, target, cv=5)
rfc = rfscore.mean()
print('Cross Val Score: ', rfc*100)
# Out:
# R2 Score:  89.45148123666394
# Cross Val Score:  21.961943188470414

# %%
import pickle
filename = 'avacoda.pkl'
pickle.dump(rf, open(filename,'wb'))

# %% [markdown]
# # Conclusion

# %%
loaded_model = pickle.load(open('avacoda.pkl', 'rb'))
result = loaded_model.score(features_test, target_test)
print(result)
# Out:
# 0.8945148123666393

# %%
conclusion=pd.DataFrame([loaded_model.predict(features_test)[:],pred_decision[:]],index=["Predicted","Orginal"])

# %%
conclusion
# Out:
#              0      1       2       3       4       5       6       7     \
# Predicted  1.4188  1.129  1.7828  1.0814  1.3691  0.8394  1.6109  1.0763
# Orginal    1.4188  1.129  1.7828  1.0814  1.3691  0.8394  1.6109  1.0763
#
#              8       9     ...    3640    3641    3642    3643    3644  \
# Predicted  1.0419  1.9569  ...  0.9847  1.1208  1.4337  1.7255  1.8021
# Orginal    1.0419  1.9569  ...  0.9847  1.1208  1.4337  1.7255  1.8021
#
#              3645    3646    3647    3648    3649
# Predicted  1.3603  1.4583  1.0475  1.8795  0.8576
# Orginal    1.3603  1.4583  1.0475  1.8795  0.8576
#
# [2 rows x 3650 columns]
